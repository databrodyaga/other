# %%
# берем тестовые данные из версии 5 и перефразируем часть текстов, чтобы оценить результаты классификации на измененных данных

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option("display.max_colwidth", None)


X_test = pd.read_csv("X_test_balanced.csv",index_col=0)
y_test = pd.read_csv("y_test_balanced.csv",index_col=0)

# %%
test = X_test.merge(y_test, left_index=True, right_index=True, how='inner')
print(len(test),
      test.isna().sum())
# Out:
# 900 text                  0
# universal_category    0
# dtype: int64

# %%
test = test.sort_values(by='universal_category').reset_index()
test.head()
# Out:
#    index  \
# 0      0
# 1    180
# 2    179
# 3    178
# 4    866
#
#                                                                                                                                                                                                                                                                                                                                              text  \
# 0                              назначение платежа: Перечисление средств по соглашению №2140 о предоставлении гранта победителю конкурса на предоставление грантов Раиса РТ на развитие гражданского общества от 26.11.2024г. НДС не облагается.\nназвание статьи: Гранты\nназвание проекта: Донорство в Татарстане\nкатегория донора: отсутствует
# ...

# %%
test.to_csv("test.csv")

# %% [markdown]
# Далее в ручном режиме в тестовом наборе каждые первые 50 строк каждой сотни были скорректированы в части названий статей, проектов, доноров, после чего разделены по признакам для отправки в LLM.

# %%
test_corr = pd.read_csv('test_corr.csv', index_col=0)

# %%
test_corr.head()
# Out:
#    index  \
# 0      0
# 1    180
# 2    179
# 3    178
# 4    866
#
#                                                                                                                                                                                                                                                                                                                                            text  \
# 0                           назначение платежа: Перечисление средств по соглашению №2140 о предоставлении гранта победителю конкурса на предоставление грантов Раиса РТ на развитие гражданского общества от 26.11.2024г. НДС не облагается.\nназвание статьи: Грантик\nназвание проекта: Донорство в Татарстане\nкатегория донора: отсутствует
# ...

# %%
X_test_corr = test_corr['text']
y_test_corr = test_corr['universal_category']

# %%
X_test_corr.to_csv("X_test_corr.csv")
y_test_corr.to_csv("y_test_corr.csv")
