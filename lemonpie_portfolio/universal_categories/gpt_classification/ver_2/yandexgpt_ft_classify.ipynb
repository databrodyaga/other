# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
import time


from __future__ import annotations
from yandex_cloud_ml_sdk import YCloudML


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option("display.max_colwidth", None)

# %%
X_test = pd.read_csv('X_test_balanced.csv',index_col=0)

# %%
X_test.head(10)
# Out:
#                                                                                                                                                                                                   purpose
# 393593       Перечисление средств по соглашению №2140 о предоставлении гранта победителю конкурса на предоставление грантов Раиса РТ на развитие гражданского общества от 26.11.2024г. НДС не облагается.
# 429170                                                                                              ЗА 27/02/2025;СУМ:1500.00;КОМ:0.00;СЛЮСАРЕНКО ВИКТОРИЯ АНАТОЛЬЕВНА;Попечительский взнос котёнок Тужур
# 379020                                                                                                 Перевод с карты *6947, Благотворительное пожертвование на уставную деятельность. НДС не облагается
# 570841                                                            ОПЛАТА ПО ДОГОВОРУ НХТК.8190 (ДС НХТК.8190-2), СЧЕТ №21 ОТ 02.06.2025 (КВОТИРУЕМЫЕ РАБОЧИЕ МЕСТА). СУММА 80143-68 РУБ. БЕЗ НАЛОГА (НДС)
# 485026                                                                                                  БЛАГОТВОРИТЕЛЬНАЯ ПОМОЩЬ ПО СОГЛАШЕНИЮ №БС2025-005 ОТ 16.01.2025 СУММА 310750-00 БЕЗ НАЛОГА (НДС)
# 591200                     Выплата процентов по депозитной сделке № UNV-0000006342917 от 22.08.2025 за период с 23.08.2025 по 25.08.2025 согласно Правилам Банковского обслуживания. НДС не предусмотрен.
# 396289                                                                                                 Перевод с карты *3120, Благотворительное пожертвование на уставную деятельность. НДС не облагается
# 402359                                                                                                                        Благотворительное пожертвование на уставную деятельность. НДС не облагается
# 147304  Оплата по договору о предоставлении целевого гранта в рамках Благотворительной программы - акции "Добрый новогодний подарок" (2023-2024) № 24-1-000496 от 15.04.2024. 1 транш. НДС не облагается.
# 171375                                                                                                             Благотворительное пожертвование по договору 111-77/2024 от 29.02.2024НДС не облагается

# %%
y_pred_ygpt_ft = pd.DataFrame(columns=["universal_category"])

sdk = YCloudML(
        folder_id="YOUR_FOLDER_ID",
        auth="YOUR_YANDEX_CLOUD_TOKEN",
    )

model = sdk.models.text_classifiers(
        "cls://YOUR_FOLDER_ID/yandexgpt-lite/rc@tamr9067f9ueb6v7f49gl"
    )

for index__, text in tqdm(X_test['purpose'].items(), total=len(X_test)):
    attempts = 0
    max_attempts = 3
    while attempts < max_attempts:
        try:
            result = model.run(str(text))  # приводим текст к строке
            print(result, "\n")
            best_label = max(result, key=lambda x: x.confidence).label
            y_pred_ygpt_ft.loc[index__, "universal_category"] = best_label
            break
        except Exception as e:
            attempts += 1
            print(f"Ошибка на index {index__}, попытка {attempts}/{max_attempts}: {e}")
            time.sleep(2)
    else:
        # если все попытки неудачные, присваиваем NaN
        y_pred_ygpt_ft.loc[index__, "universal_category"] = np.nan

        
y_pred_ygpt_ft.to_csv("y_pred_ygpt_ft.csv", index=True, header=["universal_category"])
# Out:
#   0%|          | 1/900 [00:03<57:30,  3.84s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.5426563024520874), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.197499081492424), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.18790364265441895), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0392715185880661), TextClassificationLabel(label='продажа товаров', confidence=0.002379257930442691), TextClassificationLabel(label='продажа услуг', confidence=0.003915078938007355), TextClassificationLabel(label='прочие недоходные операции', confidence=0.02121645212173462), TextClassificationLabel(label='финансовые доходы', confidence=0.00020952780323568732), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.004949124064296484)), model_version='', input_tokens=46)
#   0%|          | 2/900 [00:04<27:29,  1.84s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=2.585699576229672e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.00024801091058179736), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=3.725609303728561e-06), TextClassificationLabel(label='пожертвования через платформы', confidence=3.8962051007729315e-07), TextClassificationLabel(label='продажа товаров', confidence=3.1372776447824435e-06), TextClassificationLabel(label='продажа услуг', confidence=1.365435582556529e-05), TextClassificationLabel(label='прочие недоходные операции', confidence=4.902006367046852e-06), TextClassificationLabel(label='финансовые доходы', confidence=3.7038435038994066e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.9997199177742004)), model_version='', input_tokens=52)
#   0%|          | 3/900 [00:05<20:42,  1.38s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0020903232507407665), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.6548388004302979), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.21094059944152832), TextClassificationLabel(label='пожертвования через платформы', confidence=0.11379391700029373), TextClassificationLabel(label='продажа товаров', confidence=0.0034972161520272493), TextClassificationLabel(label='продажа услуг', confidence=0.004761491436511278), TextClassificationLabel(label='прочие недоходные операции', confidence=0.008259319700300694), TextClassificationLabel(label='финансовые доходы', confidence=7.021200872259215e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0017482369439676404)), model_version='', input_tokens=23)
#   0%|          | 4/900 [00:07<29:12,  1.96s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.024630971252918243), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.08101858198642731), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.07559140026569366), TextClassificationLabel(label='пожертвования через платформы', confidence=0.003860255004838109), TextClassificationLabel(label='продажа товаров', confidence=0.03427194058895111), TextClassificationLabel(label='продажа услуг', confidence=0.7582451105117798), TextClassificationLabel(label='прочие недоходные операции', confidence=0.017996223643422127), TextClassificationLabel(label='финансовые доходы', confidence=0.0007520075305365026), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.003633463755249977)), model_version='', input_tokens=80)
#   1%|          | 5/900 [00:10<32:39,  2.19s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.027282211929559708), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.13324272632598877), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.8306849598884583), TextClassificationLabel(label='пожертвования через платформы', confidence=0.005613533314317465), TextClassificationLabel(label='продажа товаров', confidence=0.000469875056296587), TextClassificationLabel(label='продажа услуг', confidence=0.0010630241595208645), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0014823628589510918), TextClassificationLabel(label='финансовые доходы', confidence=1.011075346468715e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00015121122123673558)), model_version='', input_tokens=55)
#   1%|          | 6/900 [00:10<23:31,  1.58s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=1.3733076684729895e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=2.439302988932468e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=5.982878974464256e-06), TextClassificationLabel(label='пожертвования через платформы', confidence=3.617643926645542e-07), TextClassificationLabel(label='продажа товаров', confidence=1.944254108821042e-06), TextClassificationLabel(label='продажа услуг', confidence=3.5063405334767594e-07), TextClassificationLabel(label='прочие недоходные операции', confidence=0.00013563882384914905), TextClassificationLabel(label='финансовые доходы', confidence=0.9997585415840149), TextClassificationLabel(label='членские и учредительские взносы', confidence=7.154647028073668e-05)), model_version='', input_tokens=74)
#   1%|          | 7/900 [00:14<30:57,  2.08s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0021464491728693247), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.6237127780914307), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.2844432294368744), TextClassificationLabel(label='пожертвования через платформы', confidence=0.06631917506456375), TextClassificationLabel(label='продажа товаров', confidence=0.002799497451633215), TextClassificationLabel(label='продажа услуг', confidence=0.005932326894253492), TextClassificationLabel(label='прочие недоходные операции', confidence=0.012803308665752411), TextClassificationLabel(label='финансовые доходы', confidence=0.00011177545820828527), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0017314705764874816)), model_version='', input_tokens=23)
#   1%|          | 8/900 [00:17<35:52,  2.41s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.002751708496361971), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.5543997883796692), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.3079678416252136), TextClassificationLabel(label='пожертвования через платформы', confidence=0.11575545370578766), TextClassificationLabel(label='продажа товаров', confidence=0.0065784817561507225), TextClassificationLabel(label='продажа услуг', confidence=0.007557011675089598), TextClassificationLabel(label='прочие недоходные операции', confidence=0.002418906893581152), TextClassificationLabel(label='финансовые доходы', confidence=0.0001823832280933857), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.002388392109423876)), model_version='', input_tokens=14)
#   1%|          | 9/900 [00:20<39:12,  2.64s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.8242413401603699), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.016204098239541054), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.13402912020683289), TextClassificationLabel(label='пожертвования через платформы', confidence=0.013026717118918896), TextClassificationLabel(label='продажа товаров', confidence=0.0006292220205068588), TextClassificationLabel(label='продажа услуг', confidence=0.00218550325371325), TextClassificationLabel(label='прочие недоходные операции', confidence=0.008634342812001705), TextClassificationLabel(label='финансовые доходы', confidence=3.4205102565465495e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0010153613984584808)), model_version='', input_tokens=68)
#   1%|          | 10/900 [00:20<29:02,  1.96s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.057991981506347656), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.2837789058685303), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.5984178185462952), TextClassificationLabel(label='пожертвования через платформы', confidence=0.018075063824653625), TextClassificationLabel(label='продажа товаров', confidence=0.002649490023031831), TextClassificationLabel(label='продажа услуг', confidence=0.03425859659910202), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0039968243800103664), TextClassificationLabel(label='финансовые доходы', confidence=0.00022970825375523418), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0006016648840159178)), model_version='', input_tokens=35)
#   1%|          | 11/900 [00:23<34:43,  2.34s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.002751708496361971), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.5543997883796692), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.3079678416252136), TextClassificationLabel(label='пожертвования через платформы', confidence=0.11575545370578766), TextClassificationLabel(label='продажа товаров', confidence=0.0065784817561507225), TextClassificationLabel(label='продажа услуг', confidence=0.007557011675089598), TextClassificationLabel(label='прочие недоходные операции', confidence=0.002418906893581152), TextClassificationLabel(label='финансовые доходы', confidence=0.0001823832280933857), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.002388392109423876)), model_version='', input_tokens=14)
#   1%|▏         | 12/900 [00:26<37:39,  2.54s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00013249754556454718), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.005427373573184013), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.003479586448520422), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0003637001209426671), TextClassificationLabel(label='продажа товаров', confidence=0.0008682215702719986), TextClassificationLabel(label='продажа услуг', confidence=0.9871523976325989), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0006722212419845164), TextClassificationLabel(label='финансовые доходы', confidence=7.490731513826177e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0018290722509846091)), model_version='', input_tokens=49)
#   1%|▏         | 13/900 [00:29<38:49,  2.63s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.002609860384836793), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.41555261611938477), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.019683970138430595), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0050998879596591), TextClassificationLabel(label='продажа товаров', confidence=0.18584662675857544), TextClassificationLabel(label='продажа услуг', confidence=0.022217901423573494), TextClassificationLabel(label='прочие недоходные операции', confidence=0.25057289004325867), TextClassificationLabel(label='финансовые доходы', confidence=0.001528276363387704), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.09688789397478104)), model_version='', input_tokens=66)
#   2%|▏         | 14/900 [00:32<39:48,  2.70s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.002751708496361971), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.5543997883796692), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.3079678416252136), TextClassificationLabel(label='пожертвования через платформы', confidence=0.11575545370578766), TextClassificationLabel(label='продажа товаров', confidence=0.0065784817561507225), TextClassificationLabel(label='продажа услуг', confidence=0.007557011675089598), TextClassificationLabel(label='прочие недоходные операции', confidence=0.002418906893581152), TextClassificationLabel(label='финансовые доходы', confidence=0.0001823832280933857), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.002388392109423876)), model_version='', input_tokens=14)
#   2%|▏         | 15/900 [00:33<29:43,  2.02s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=1.1205495866306592e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=1.118363161367597e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=1.917320696520619e-05), TextClassificationLabel(label='пожертвования через платформы', confidence=2.387762378930347e-07), TextClassificationLabel(label='продажа товаров', confidence=5.105261607241118e-06), TextClassificationLabel(label='продажа услуг', confidence=2.774741551547777e-05), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0010116462362930179), TextClassificationLabel(label='финансовые доходы', confidence=0.9983561635017395), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0005575939430855215)), model_version='', input_tokens=90)
#   2%|▏         | 16/900 [00:35<33:21,  2.26s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00030397536465898156), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.011490441858768463), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.005757691338658333), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0004138652002438903), TextClassificationLabel(label='продажа товаров', confidence=0.0020671761594712734), TextClassificationLabel(label='продажа услуг', confidence=0.9740444421768188), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0018171642441302538), TextClassificationLabel(label='финансовые доходы', confidence=0.00019397471623960882), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0039113350212574005)), model_version='', input_tokens=49)
#   2%|▏         | 17/900 [00:38<34:14,  2.33s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=9.51978872762993e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.9018538594245911), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.07773306220769882), TextClassificationLabel(label='пожертвования через платформы', confidence=0.011187578551471233), TextClassificationLabel(label='продажа товаров', confidence=0.004284857306629419), TextClassificationLabel(label='продажа услуг', confidence=0.002561730332672596), TextClassificationLabel(label='прочие недоходные операции', confidence=0.000781665148679167), TextClassificationLabel(label='финансовые доходы', confidence=8.804364915704355e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0014140312559902668)), model_version='', input_tokens=11)
#   2%|▏         | 18/900 [00:38<25:41,  1.75s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0008441486279480159), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.04804207757115364), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.007564334198832512), TextClassificationLabel(label='пожертвования через платформы', confidence=0.01465558260679245), TextClassificationLabel(label='продажа товаров', confidence=0.9060449600219727), TextClassificationLabel(label='продажа услуг', confidence=0.015530481934547424), TextClassificationLabel(label='прочие недоходные операции', confidence=0.004216358065605164), TextClassificationLabel(label='финансовые доходы', confidence=0.00020128762116655707), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.002900688676163554)), model_version='', input_tokens=54)
#   2%|▏         | 19/900 [00:41<28:32,  1.94s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=4.699758574133739e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.028130996972322464), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0024894641246646643), TextClassificationLabel(label='пожертвования через платформы', confidence=0.003603076096624136), TextClassificationLabel(label='продажа товаров', confidence=0.9611420035362244), TextClassificationLabel(label='продажа услуг', confidence=0.0012505593476817012), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0018347195582464337), TextClassificationLabel(label='финансовые доходы', confidence=1.1929357242479455e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0014901604736223817)), model_version='', input_tokens=53)
#   2%|▏         | 20/900 [00:43<32:12,  2.20s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.9224673509597778), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.008445996791124344), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.014349597506225109), TextClassificationLabel(label='пожертвования через платформы', confidence=0.000739445851650089), TextClassificationLabel(label='продажа товаров', confidence=0.0059715877287089825), TextClassificationLabel(label='продажа услуг', confidence=0.03272648900747299), TextClassificationLabel(label='прочие недоходные операции', confidence=0.00827657338231802), TextClassificationLabel(label='финансовые доходы', confidence=0.001112209865823388), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.005910668522119522)), model_version='', input_tokens=110)
#   2%|▏         | 21/900 [00:46<35:43,  2.44s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.007750071585178375), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.11331790685653687), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.8521609306335449), TextClassificationLabel(label='пожертвования через платформы', confidence=0.009310788474977016), TextClassificationLabel(label='продажа товаров', confidence=0.002476769033819437), TextClassificationLabel(label='продажа услуг', confidence=0.010273446328938007), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0017055851640179753), TextClassificationLabel(label='финансовые доходы', confidence=8.190258813556284e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0029226255137473345)), model_version='', input_tokens=50)
#   2%|▏         | 22/900 [00:50<38:40,  2.64s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=2.747264602476207e-07), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=1.8226659292963632e-08), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=3.6644988199441286e-07), TextClassificationLabel(label='пожертвования через платформы', confidence=6.129975105295671e-08), TextClassificationLabel(label='продажа товаров', confidence=3.618271193772671e-07), TextClassificationLabel(label='продажа услуг', confidence=1.770306283788159e-07), TextClassificationLabel(label='прочие недоходные операции', confidence=6.439602293539792e-05), TextClassificationLabel(label='финансовые доходы', confidence=0.9999319314956665), TextClassificationLabel(label='членские и учредительские взносы', confidence=2.337621253900579e-06)), model_version='', input_tokens=25)
#   3%|▎         | 23/900 [00:53<40:22,  2.76s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.000618761230725795), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.0025157793425023556), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.002151531632989645), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0017097064992412925), TextClassificationLabel(label='продажа товаров', confidence=0.0007198815583251417), TextClassificationLabel(label='продажа услуг', confidence=0.007185841910541058), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9824814200401306), TextClassificationLabel(label='финансовые доходы', confidence=0.0012833276996389031), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.001333798049017787)), model_version='', input_tokens=18)
#   3%|▎         | 24/900 [00:55<37:46,  2.59s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0021709848660975695), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.6508674025535583), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.2334377020597458), TextClassificationLabel(label='пожертвования через платформы', confidence=0.08791345357894897), TextClassificationLabel(label='продажа товаров', confidence=0.004835391882807016), TextClassificationLabel(label='продажа услуг', confidence=0.006148428190499544), TextClassificationLabel(label='прочие недоходные операции', confidence=0.01260652020573616), TextClassificationLabel(label='финансовые доходы', confidence=0.00012661352229770273), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0018935665721073747)), model_version='', input_tokens=23)
#   3%|▎         | 25/900 [00:57<37:00,  2.54s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0007359115406870842), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.8342705368995667), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.013117797672748566), TextClassificationLabel(label='пожертвования через платформы', confidence=0.004587947390973568), TextClassificationLabel(label='продажа товаров', confidence=0.08572693914175034), TextClassificationLabel(label='продажа услуг', confidence=0.05154102295637131), TextClassificationLabel(label='прочие недоходные операции', confidence=0.00518614798784256), TextClassificationLabel(label='финансовые доходы', confidence=0.0007926079561002553), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.004040949512273073)), model_version='', input_tokens=29)
#   3%|▎         | 26/900 [01:00<39:16,  2.70s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.001824547303840518), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.7009971737861633), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.2150484323501587), TextClassificationLabel(label='пожертвования через платформы', confidence=0.057823002338409424), TextClassificationLabel(label='продажа товаров', confidence=0.004969330504536629), TextClassificationLabel(label='продажа услуг', confidence=0.005052517168223858), TextClassificationLabel(label='прочие недоходные операции', confidence=0.012359412387013435), TextClassificationLabel(label='финансовые доходы', confidence=9.390564082423225e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.001831688336096704)), model_version='', input_tokens=23)
#   3%|▎         | 27/900 [01:03<39:24,  2.71s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.668685793876648), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.02858753129839897), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.21836625039577484), TextClassificationLabel(label='пожертвования через платформы', confidence=0.037067338824272156), TextClassificationLabel(label='продажа товаров', confidence=0.0028112654108554125), TextClassificationLabel(label='продажа услуг', confidence=0.004166970495134592), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0287274569272995), TextClassificationLabel(label='финансовые доходы', confidence=0.00028803141321986914), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.011299381032586098)), model_version='', input_tokens=49)
#   3%|▎         | 28/900 [01:03<29:16,  2.01s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=1.400518272021145e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=5.644080738420598e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=1.6534399946976919e-06), TextClassificationLabel(label='пожертвования через платформы', confidence=1.4792422007303685e-06), TextClassificationLabel(label='продажа товаров', confidence=1.1841471859952435e-05), TextClassificationLabel(label='продажа услуг', confidence=3.0445675292867236e-05), TextClassificationLabel(label='прочие недоходные операции', confidence=3.083005140069872e-06), TextClassificationLabel(label='финансовые доходы', confidence=4.627700400305912e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.999847412109375)), model_version='', input_tokens=26)
#   3%|▎         | 29/900 [01:06<31:35,  2.18s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00022604278638027608), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.021755432710051537), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.008305956609547138), TextClassificationLabel(label='пожертвования через платформы', confidence=0.002977529773488641), TextClassificationLabel(label='продажа товаров', confidence=0.009415904060006142), TextClassificationLabel(label='продажа услуг', confidence=0.015589717775583267), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9373409152030945), TextClassificationLabel(label='финансовые доходы', confidence=0.0009479653090238571), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0034405291080474854)), model_version='', input_tokens=8)
#   3%|▎         | 30/900 [01:06<23:44,  1.64s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0021901109721511602), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.14565163850784302), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.13287660479545593), TextClassificationLabel(label='пожертвования через платформы', confidence=0.03035002574324608), TextClassificationLabel(label='продажа товаров', confidence=0.34130629897117615), TextClassificationLabel(label='продажа услуг', confidence=0.33470484614372253), TextClassificationLabel(label='прочие недоходные операции', confidence=0.00704908324405551), TextClassificationLabel(label='финансовые доходы', confidence=3.887912316713482e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.005832492373883724)), model_version='', input_tokens=25)
#   3%|▎         | 31/900 [01:09<26:37,  1.84s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0017947853775694966), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.10080679506063461), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.8053933382034302), TextClassificationLabel(label='пожертвования через платформы', confidence=0.006255246698856354), TextClassificationLabel(label='продажа товаров', confidence=0.002933206968009472), TextClassificationLabel(label='продажа услуг', confidence=0.07990063726902008), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0021628113463521004), TextClassificationLabel(label='финансовые доходы', confidence=0.00041358673479408026), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.000339543359586969)), model_version='', input_tokens=11)
#   4%|▎         | 32/900 [01:12<31:40,  2.19s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=2.8772736186510883e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=1.2939720761551143e-07), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=4.490690571401501e-06), TextClassificationLabel(label='пожертвования через платформы', confidence=1.0197775281994836e-06), TextClassificationLabel(label='продажа товаров', confidence=4.412442194734467e-06), TextClassificationLabel(label='продажа услуг', confidence=4.0968138819152955e-06), TextClassificationLabel(label='прочие недоходные операции', confidence=0.1216663345694542), TextClassificationLabel(label='финансовые доходы', confidence=0.8781741261482239), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00011666781210806221)), model_version='', input_tokens=23)
#   4%|▎         | 33/900 [01:14<33:15,  2.30s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.02157554216682911), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.34651556611061096), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.5825755596160889), TextClassificationLabel(label='пожертвования через платформы', confidence=0.012353547848761082), TextClassificationLabel(label='продажа товаров', confidence=0.003266977146267891), TextClassificationLabel(label='продажа услуг', confidence=0.005349639803171158), TextClassificationLabel(label='прочие недоходные операции', confidence=0.012634159065783024), TextClassificationLabel(label='финансовые доходы', confidence=0.0002945269225165248), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.015434409491717815)), model_version='', input_tokens=18)
#   4%|▍         | 34/900 [01:17<36:12,  2.51s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00019495609740260988), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.29394084215164185), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.006008900236338377), TextClassificationLabel(label='пожертвования через платформы', confidence=0.01525834295898676), TextClassificationLabel(label='продажа товаров', confidence=0.013360654003918171), TextClassificationLabel(label='продажа услуг', confidence=0.6534112095832825), TextClassificationLabel(label='прочие недоходные операции', confidence=0.013481889851391315), TextClassificationLabel(label='финансовые доходы', confidence=0.00022351827647071332), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.004119782242923975)), model_version='', input_tokens=75)
#   4%|▍         | 35/900 [01:20<38:27,  2.67s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=8.347423863597214e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=2.140657488780562e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=7.9379889939446e-05), TextClassificationLabel(label='пожертвования через платформы', confidence=1.8550234699432622e-06), TextClassificationLabel(label='продажа товаров', confidence=9.985679935198277e-05), TextClassificationLabel(label='продажа услуг', confidence=2.924067302956246e-06), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9996525049209595), TextClassificationLabel(label='финансовые доходы', confidence=4.183026612736285e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=1.6826843420858495e-05)), model_version='', input_tokens=43)
#   4%|▍         | 36/900 [01:23<38:16,  2.66s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00011454174818936735), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=7.119007204892114e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.000693690322805196), TextClassificationLabel(label='пожертвования через платформы', confidence=5.90186427871231e-05), TextClassificationLabel(label='продажа товаров', confidence=9.486575436312705e-05), TextClassificationLabel(label='продажа услуг', confidence=7.803444168530405e-05), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9928373694419861), TextClassificationLabel(label='финансовые доходы', confidence=0.003982907626777887), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0020683242473751307)), model_version='', input_tokens=23)
#   4%|▍         | 37/900 [01:23<28:25,  1.98s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.7022122740745544), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.038247548043727875), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.17999115586280823), TextClassificationLabel(label='пожертвования через платформы', confidence=0.024942900985479355), TextClassificationLabel(label='продажа товаров', confidence=0.002582523273304105), TextClassificationLabel(label='продажа услуг', confidence=0.007491045631468296), TextClassificationLabel(label='прочие недоходные операции', confidence=0.033246275037527084), TextClassificationLabel(label='финансовые доходы', confidence=0.0004585212445817888), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.010827797465026379)), model_version='', input_tokens=49)
#   4%|▍         | 38/900 [01:26<33:20,  2.32s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0002526763710193336), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.01026709470897913), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.004330412484705448), TextClassificationLabel(label='пожертвования через платформы', confidence=0.00036692462163046), TextClassificationLabel(label='продажа товаров', confidence=0.001731795840896666), TextClassificationLabel(label='продажа услуг', confidence=0.9785511493682861), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0012957892613485456), TextClassificationLabel(label='финансовые доходы', confidence=0.00013954115274827927), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0030647306703031063)), model_version='', input_tokens=49)
#   4%|▍         | 39/900 [01:29<35:45,  2.49s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=4.488623744691722e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.02289116568863392), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.001978836255148053), TextClassificationLabel(label='пожертвования через платформы', confidence=0.003371459199115634), TextClassificationLabel(label='продажа товаров', confidence=0.9657824039459229), TextClassificationLabel(label='продажа услуг', confidence=0.002695519244298339), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0013666896848008037), TextClassificationLabel(label='финансовые доходы', confidence=2.808909266605042e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0018408790929242969)), model_version='', input_tokens=53)
#   4%|▍         | 40/900 [01:32<37:02,  2.58s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.004837512969970703), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.4282894432544708), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.4031272828578949), TextClassificationLabel(label='пожертвования через платформы', confidence=0.07489947229623795), TextClassificationLabel(label='продажа товаров', confidence=0.06245874613523483), TextClassificationLabel(label='продажа услуг', confidence=0.009179987944662571), TextClassificationLabel(label='прочие недоходные операции', confidence=0.013855008408427238), TextClassificationLabel(label='финансовые доходы', confidence=0.001553729991428554), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0017988417530432343)), model_version='', input_tokens=50)
#   5%|▍         | 41/900 [01:33<27:33,  1.93s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.86943119764328), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.01491926982998848), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.03293057903647423), TextClassificationLabel(label='пожертвования через платформы', confidence=0.004880374763160944), TextClassificationLabel(label='продажа товаров', confidence=0.0037492290139198303), TextClassificationLabel(label='продажа услуг', confidence=0.037958428263664246), TextClassificationLabel(label='прочие недоходные операции', confidence=0.03404233232140541), TextClassificationLabel(label='финансовые доходы', confidence=0.0006102542974986136), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0014782899525016546)), model_version='', input_tokens=131)
#   5%|▍         | 42/900 [01:35<29:39,  2.07s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.01924287900328636), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.31208449602127075), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.6366146802902222), TextClassificationLabel(label='пожертвования через платформы', confidence=0.011128771118819714), TextClassificationLabel(label='продажа товаров', confidence=0.0030986585188657045), TextClassificationLabel(label='продажа услуг', confidence=0.006715422496199608), TextClassificationLabel(label='прочие недоходные операции', confidence=0.010044805705547333), TextClassificationLabel(label='финансовые доходы', confidence=0.00016762551967985928), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0009026419138535857)), model_version='', input_tokens=72)
#   5%|▍         | 43/900 [01:35<22:22,  1.57s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0025069406256079674), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.6529908776283264), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.2301184982061386), TextClassificationLabel(label='пожертвования через платформы', confidence=0.09108895808458328), TextClassificationLabel(label='продажа товаров', confidence=0.00399826280772686), TextClassificationLabel(label='продажа услуг', confidence=0.006417345721274614), TextClassificationLabel(label='прочие недоходные операции', confidence=0.010637395083904266), TextClassificationLabel(label='финансовые доходы', confidence=8.9025947090704e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0021526922937482595)), model_version='', input_tokens=23)
#   5%|▍         | 44/900 [01:37<24:55,  1.75s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=4.388054094306426e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=4.501567309489474e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=9.289510671806056e-06), TextClassificationLabel(label='пожертвования через платформы', confidence=9.019958611133916e-07), TextClassificationLabel(label='продажа товаров', confidence=4.7446178541576955e-06), TextClassificationLabel(label='продажа услуг', confidence=9.162001219920057e-07), TextClassificationLabel(label='прочие недоходные операции', confidence=0.00041638908442109823), TextClassificationLabel(label='финансовые доходы', confidence=0.9993129968643188), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00020532392954919487)), model_version='', input_tokens=74)
#   5%|▌         | 45/900 [01:40<27:57,  1.96s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0005803668755106628), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.004921435844153166), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.02027961239218712), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0005484080174937844), TextClassificationLabel(label='продажа товаров', confidence=0.00447445921599865), TextClassificationLabel(label='продажа услуг', confidence=0.008278152905404568), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9516990184783936), TextClassificationLabel(label='финансовые доходы', confidence=0.00046451971866190434), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.008754152804613113)), model_version='', input_tokens=9)
#   5%|▌         | 46/900 [01:40<21:10,  1.49s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=1.3644621503772214e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=4.945165343883673e-08), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=3.0204188306015567e-07), TextClassificationLabel(label='пожертвования через платформы', confidence=6.058038515277531e-09), TextClassificationLabel(label='продажа товаров', confidence=3.863174242724199e-07), TextClassificationLabel(label='продажа услуг', confidence=1.650211487458364e-07), TextClassificationLabel(label='прочие недоходные операции', confidence=0.999995231628418), TextClassificationLabel(label='финансовые доходы', confidence=9.757176258062827e-07), TextClassificationLabel(label='членские и учредительские взносы', confidence=1.577860416546173e-06)), model_version='', input_tokens=35)
#   5%|▌         | 47/900 [01:43<26:35,  1.87s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0019388303626328707), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.03495895862579346), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.5079811215400696), TextClassificationLabel(label='пожертвования через платформы', confidence=0.035044409334659576), TextClassificationLabel(label='продажа товаров', confidence=0.04521816968917847), TextClassificationLabel(label='продажа услуг', confidence=0.36660036444664), TextClassificationLabel(label='прочие недоходные операции', confidence=0.006520659197121859), TextClassificationLabel(label='финансовые доходы', confidence=0.0005383937386795878), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0011991538340225816)), model_version='', input_tokens=30)
#   5%|▌         | 48/900 [01:43<20:14,  1.43s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.05106336995959282), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.24346104264259338), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.10522384196519852), TextClassificationLabel(label='пожертвования через платформы', confidence=0.05449619144201279), TextClassificationLabel(label='продажа товаров', confidence=0.0051828110590577126), TextClassificationLabel(label='продажа услуг', confidence=0.18849992752075195), TextClassificationLabel(label='прочие недоходные операции', confidence=0.3376822769641876), TextClassificationLabel(label='финансовые доходы', confidence=0.007826043292880058), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.006564496085047722)), model_version='', input_tokens=3)
#   5%|▌         | 49/900 [01:46<25:18,  1.78s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0019107311964035034), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.09906024485826492), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.11137642711400986), TextClassificationLabel(label='пожертвования через платформы', confidence=0.026590200141072273), TextClassificationLabel(label='продажа товаров', confidence=0.5864271521568298), TextClassificationLabel(label='продажа услуг', confidence=0.1550845354795456), TextClassificationLabel(label='прочие недоходные операции', confidence=0.01648203656077385), TextClassificationLabel(label='финансовые доходы', confidence=0.00023361602507065982), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.002834930084645748)), model_version='', input_tokens=25)
#   6%|▌         | 50/900 [01:46<19:18,  1.36s/it]
# ...
#  98%|█████████▊| 885/900 [30:36<00:33,  2.24s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0012498393189162016), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.8026018142700195), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0865996852517128), TextClassificationLabel(label='пожертвования через платформы', confidence=0.08744953572750092), TextClassificationLabel(label='продажа товаров', confidence=0.004666445776820183), TextClassificationLabel(label='продажа услуг', confidence=0.014452840201556683), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0007700035930611193), TextClassificationLabel(label='финансовые доходы', confidence=2.6972902560373768e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00218285177834332)), model_version='', input_tokens=45)
#  98%|█████████▊| 886/900 [30:39<00:33,  2.37s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.2990773916244507), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.02542198821902275), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.1035604476928711), TextClassificationLabel(label='пожертвования через платформы', confidence=0.006857285741716623), TextClassificationLabel(label='продажа товаров', confidence=0.035260479897260666), TextClassificationLabel(label='продажа услуг', confidence=0.4242452383041382), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0994473323225975), TextClassificationLabel(label='финансовые доходы', confidence=0.001112881232984364), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.005016897339373827)), model_version='', input_tokens=127)
#  99%|█████████▊| 887/900 [30:41<00:32,  2.49s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.002494819462299347), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.14471454918384552), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.16254813969135284), TextClassificationLabel(label='пожертвования через платформы', confidence=0.02430260181427002), TextClassificationLabel(label='продажа товаров', confidence=0.49824467301368713), TextClassificationLabel(label='продажа услуг', confidence=0.12858615815639496), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0353277213871479), TextClassificationLabel(label='финансовые доходы', confidence=0.0001655181695241481), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.003615788882598281)), model_version='', input_tokens=25)
#  99%|█████████▊| 888/900 [30:44<00:32,  2.69s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.002209931844845414), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.6809102296829224), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.20404742658138275), TextClassificationLabel(label='пожертвования через платформы', confidence=0.09287392348051071), TextClassificationLabel(label='продажа товаров', confidence=0.0028907516971230507), TextClassificationLabel(label='продажа услуг', confidence=0.006051377858966589), TextClassificationLabel(label='прочие недоходные операции', confidence=0.009822354651987553), TextClassificationLabel(label='финансовые доходы', confidence=7.832550909370184e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0011155727552250028)), model_version='', input_tokens=23)
#  99%|█████████▉| 889/900 [30:47<00:29,  2.72s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0006348442402668297), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.06937121599912643), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.9245579838752747), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0017655310221016407), TextClassificationLabel(label='продажа товаров', confidence=0.0002543799055274576), TextClassificationLabel(label='продажа услуг', confidence=0.0003250392619520426), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0005173863028176129), TextClassificationLabel(label='финансовые доходы', confidence=5.658533609675942e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.002567891962826252)), model_version='', input_tokens=53)
#  99%|█████████▉| 890/900 [30:48<00:20,  2.02s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0009283582912757993), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.11245325207710266), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.008035470731556416), TextClassificationLabel(label='пожертвования через платформы', confidence=0.002166945720091462), TextClassificationLabel(label='продажа товаров', confidence=0.7135080695152283), TextClassificationLabel(label='продажа услуг', confidence=0.08681230247020721), TextClassificationLabel(label='прочие недоходные операции', confidence=0.023345258086919785), TextClassificationLabel(label='финансовые доходы', confidence=0.0011396721238270402), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.05161069333553314)), model_version='', input_tokens=47)
#  99%|█████████▉| 891/900 [30:51<00:20,  2.30s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.002157683949917555), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.6282030940055847), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.272838294506073), TextClassificationLabel(label='пожертвования через платформы', confidence=0.07236557453870773), TextClassificationLabel(label='продажа товаров', confidence=0.004038965329527855), TextClassificationLabel(label='продажа услуг', confidence=0.007092067506164312), TextClassificationLabel(label='прочие недоходные операции', confidence=0.010793010704219341), TextClassificationLabel(label='финансовые доходы', confidence=9.24252308323048e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0024188526440411806)), model_version='', input_tokens=23)
#  99%|█████████▉| 892/900 [30:53<00:19,  2.46s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0013132928870618343), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.0016796246636658907), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.005107095465064049), TextClassificationLabel(label='пожертвования через платформы', confidence=0.00014374971215147525), TextClassificationLabel(label='продажа товаров', confidence=0.0006801225244998932), TextClassificationLabel(label='продажа услуг', confidence=0.00012271573359612375), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9904991984367371), TextClassificationLabel(label='финансовые доходы', confidence=0.0003274436166975647), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00012685869296547025)), model_version='', input_tokens=50)
#  99%|█████████▉| 893/900 [30:56<00:16,  2.41s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.5927934050559998), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.05767177417874336), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.23904286324977875), TextClassificationLabel(label='пожертвования через платформы', confidence=0.031966228038072586), TextClassificationLabel(label='продажа товаров', confidence=0.0037742641288787127), TextClassificationLabel(label='продажа услуг', confidence=0.008211610838770866), TextClassificationLabel(label='прочие недоходные операции', confidence=0.04528919979929924), TextClassificationLabel(label='финансовые доходы', confidence=0.0008621231536380947), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.020388539880514145)), model_version='', input_tokens=49)
#  99%|█████████▉| 894/900 [30:59<00:15,  2.61s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=2.8772736186510883e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=1.2939720761551143e-07), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=4.490690571401501e-06), TextClassificationLabel(label='пожертвования через платформы', confidence=1.0197775281994836e-06), TextClassificationLabel(label='продажа товаров', confidence=4.412442194734467e-06), TextClassificationLabel(label='продажа услуг', confidence=4.0968138819152955e-06), TextClassificationLabel(label='прочие недоходные операции', confidence=0.1216663345694542), TextClassificationLabel(label='финансовые доходы', confidence=0.8781741261482239), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00011666781210806221)), model_version='', input_tokens=23)
#  99%|█████████▉| 895/900 [31:01<00:13,  2.60s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.037672434002161026), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.25544092059135437), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.6421783566474915), TextClassificationLabel(label='пожертвования через платформы', confidence=0.020870830863714218), TextClassificationLabel(label='продажа товаров', confidence=0.0018393226200714707), TextClassificationLabel(label='продажа услуг', confidence=0.03535543009638786), TextClassificationLabel(label='прочие недоходные операции', confidence=0.005493884440511465), TextClassificationLabel(label='финансовые доходы', confidence=0.00018900283612310886), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0009598355973139405)), model_version='', input_tokens=37)
# 100%|█████████▉| 896/900 [31:04<00:10,  2.53s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0017547599272802472), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.6592105627059937), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.24109318852424622), TextClassificationLabel(label='пожертвования через платформы', confidence=0.08154860883951187), TextClassificationLabel(label='продажа товаров', confidence=0.0025706735905259848), TextClassificationLabel(label='продажа услуг', confidence=0.004330367315560579), TextClassificationLabel(label='прочие недоходные операции', confidence=0.007841281592845917), TextClassificationLabel(label='финансовые доходы', confidence=6.678861245745793e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0015837461687624454)), model_version='', input_tokens=23)
# 100%|█████████▉| 897/900 [31:07<00:08,  2.70s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.010490592569112778), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.19712312519550323), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.7645574808120728), TextClassificationLabel(label='пожертвования через платформы', confidence=0.022224856540560722), TextClassificationLabel(label='продажа товаров', confidence=0.0014097308740019798), TextClassificationLabel(label='продажа услуг', confidence=0.0016052534338086843), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0024572990369051695), TextClassificationLabel(label='финансовые доходы', confidence=3.4306463930988684e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=9.734900231705979e-05)), model_version='', input_tokens=42)
# 100%|█████████▉| 898/900 [31:10<00:05,  2.76s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=2.102115637114821e-08), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=1.0293086916135508e-06), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=3.9813308205793874e-08), TextClassificationLabel(label='пожертвования через платформы', confidence=1.624389156518191e-08), TextClassificationLabel(label='продажа товаров', confidence=1.048784525892188e-08), TextClassificationLabel(label='продажа услуг', confidence=6.417703843908384e-07), TextClassificationLabel(label='прочие недоходные операции', confidence=2.8990487521696195e-07), TextClassificationLabel(label='финансовые доходы', confidence=2.5755662491633302e-08), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.9999979734420776)), model_version='', input_tokens=51)
# 100%|█████████▉| 899/900 [31:13<00:02,  2.88s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=9.131661499850452e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.020564571022987366), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0022232283372431993), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0059317187406122684), TextClassificationLabel(label='продажа товаров', confidence=0.9613093137741089), TextClassificationLabel(label='продажа услуг', confidence=0.005985361523926258), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0023550866171717644), TextClassificationLabel(label='финансовые доходы', confidence=4.520500442595221e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.001494063064455986)), model_version='', input_tokens=54)
# 100%|██████████| 900/900 [31:13<00:00,  2.08s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.002751708496361971), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.5543997883796692), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.3079678416252136), TextClassificationLabel(label='пожертвования через платформы', confidence=0.11575545370578766), TextClassificationLabel(label='продажа товаров', confidence=0.0065784817561507225), TextClassificationLabel(label='продажа услуг', confidence=0.007557011675089598), TextClassificationLabel(label='прочие недоходные операции', confidence=0.002418906893581152), TextClassificationLabel(label='финансовые доходы', confidence=0.0001823832280933857), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.002388392109423876)), model_version='', input_tokens=14)

# %%
y_pred_ygpt_ft.to_csv("y_pred_ygpt_ft.csv", index=True, header=["universal_category"])
