# %% [markdown]
# Проверим метрики для прогнозов gpt
#
# Здесь просто взяли модель обученную для версии 2 и протестировали на другом тестовом наборе в 900 сбалансированных данных - результат аналоагичный версии 2, подтвердили.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option("display.max_colwidth", None)

y_true = pd.read_csv('/Users/roman_yakovlev/Documents/LemonPie/Сегментация_своя/gpt_classification/ver_4/y_test_balanced.csv', index_col=0)
y_pred_ygpt_ft = pd.read_csv('/Users/roman_yakovlev/Documents/LemonPie/Сегментация_своя/gpt_classification/ver_4/y_pred_ygpt_ft.csv',index_col=0)

# %%
# сверка индексов
print(y_true.index.equals(y_pred_ygpt_ft.index))

# проверка, что множества индексов совпадают (порядок не важен)
print(set(y_true.index) == set(y_pred_ygpt_ft.index))

# вывод различий
print("Есть в y_true, но нет в y_pred:", y_true.index.difference(y_pred_ygpt_ft.index))
print("Есть в y_pred, но нет в y_true:", y_pred_ygpt_ft.index.difference(y_true.index))
# Out:
# True
# True
# Есть в y_true, но нет в y_pred: Index([], dtype='int64')
# Есть в y_pred, но нет в y_true: Index([], dtype='int64')

# %%
# считаем метрики для прогнозов YandexGPT дообученой на нашем датасете

accuracy = accuracy_score(y_true, y_pred_ygpt_ft)

precision = precision_score(y_true, y_pred_ygpt_ft, average='weighted')
recall = recall_score(y_true, y_pred_ygpt_ft, average='weighted')
f1 = f1_score(y_true, y_pred_ygpt_ft, average='weighted')

print("Accuracy:", accuracy)
print("Precision (weighted):", precision)
print("Recall (weighted):", recall)
print("F1-score (weighted):", f1)

print("\nОтчет по классам:")
print(classification_report(y_true, y_pred_ygpt_ft))
# Out:
# Accuracy: 0.6988888888888889
# Precision (weighted): 0.8361341625768753
# Recall (weighted): 0.6988888888888889
# F1-score (weighted): 0.6837513458669355
#
# Отчет по классам:
#                                              precision    recall  f1-score   support
#
#                    гранты субсидии конкурсы       1.00      0.61      0.76       100
#  пожертвования от физических лиц (напрямую)       0.33      0.98      0.49       100
# пожертвования от юридических лиц (напрямую)       0.59      0.43      0.50       100
#               пожертвования через платформы       1.00      0.01      0.02       100
#                             продажа товаров       0.78      0.82      0.80       100
#                               продажа услуг       0.94      0.58      0.72       100
#                  прочие недоходные операции       0.92      0.98      0.95       100
#                           финансовые доходы       1.00      0.98      0.99       100
#            членские и учредительские взносы       0.98      0.90      0.94       100
#
#                                    accuracy                           0.70       900
#                                   macro avg       0.84      0.70      0.68       900
#                                weighted avg       0.84      0.70      0.68       900
