# %% [markdown]
# Проверим метрики для прогнозов gpt
#
# В этой версии еще больше сдвинули баланс классов в обучающей выборке в пользу малых классов, chatgpt вооще не пробовали - дорабатываем ygpt как наиболее доступный API. Тестировали на том же сбалансированном датасете в 900 строк по 100 на класс, результаты хуже чем в предыдущем тесте.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option("display.max_colwidth", None)

y_true = pd.read_csv('/Users/roman_yakovlev/Documents/LemonPie/Сегментация_своя/gpt_classification/ver_3/y_test_balanced.csv', index_col=0)
y_pred_ygpt = pd.read_csv('/Users/roman_yakovlev/Documents/LemonPie/Сегментация_своя/gpt_classification/ver_3/y_pred_ygpt.csv',index_col=0)
y_pred_ygpt_ft = pd.read_csv('/Users/roman_yakovlev/Documents/LemonPie/Сегментация_своя/gpt_classification/ver_3/y_pred_ygpt_ft.csv',index_col=0)

# %%
# сверка индексов
print(y_true.index.equals(y_pred_ygpt.index))

# проверка, что множества индексов совпадают (порядок не важен)
print(set(y_true.index) == set(y_pred_ygpt.index))

# вывод различий
print("Есть в y_true, но нет в y_pred:", y_true.index.difference(y_pred_ygpt.index))
print("Есть в y_pred, но нет в y_true:", y_pred_ygpt.index.difference(y_true.index))
# Out:
# True
# True
# Есть в y_true, но нет в y_pred: Index([], dtype='int64')
# Есть в y_pred, но нет в y_true: Index([], dtype='int64')

# %%
# считаем метрики для прогнозов YandexGPT

accuracy = accuracy_score(y_true, y_pred_ygpt)

precision = precision_score(y_true, y_pred_ygpt, average='weighted')
recall = recall_score(y_true, y_pred_ygpt, average='weighted')
f1 = f1_score(y_true, y_pred_ygpt, average='weighted')

print("Accuracy:", accuracy)
print("Precision (weighted):", precision)
print("Recall (weighted):", recall)
print("F1-score (weighted):", f1)

print("\nОтчет по классам:")
print(classification_report(y_true, y_pred_ygpt))
# Out:
# Accuracy: 0.4477777777777778
# Precision (weighted): 0.5288446822487014
# Recall (weighted): 0.4477777777777778
# F1-score (weighted): 0.40508432012312606
#
# Отчет по классам:
#                                              precision    recall  f1-score   support
#
#                    гранты субсидии конкурсы       1.00      0.78      0.88       100
#  пожертвования от физических лиц (напрямую)       0.22      0.74      0.34       100
# пожертвования от юридических лиц (напрямую)       0.17      0.02      0.04       100
#               пожертвования через платформы       0.00      0.00      0.00       100
#                             продажа товаров       0.86      0.18      0.30       100
#                               продажа услуг       0.35      0.36      0.35       100
#                  прочие недоходные операции       0.75      0.15      0.25       100
#                           финансовые доходы       0.44      1.00      0.62       100
#            членские и учредительские взносы       0.98      0.80      0.88       100
#
#                                    accuracy                           0.45       900
#                                   macro avg       0.53      0.45      0.41       900
#                                weighted avg       0.53      0.45      0.41       900

# %%
# сверка индексов
print(y_true.index.equals(y_pred_ygpt_ft.index))

# проверка, что множества индексов совпадают (порядок не важен)
print(set(y_true.index) == set(y_pred_ygpt_ft.index))

# вывод различий
print("Есть в y_true, но нет в y_pred:", y_true.index.difference(y_pred_ygpt_ft.index))
print("Есть в y_pred, но нет в y_true:", y_pred_ygpt_ft.index.difference(y_true.index))
# Out:
# True
# True
# Есть в y_true, но нет в y_pred: Index([], dtype='int64')
# Есть в y_pred, но нет в y_true: Index([], dtype='int64')

# %%
# считаем метрики для прогнозов YandexGPT дообученой на нашем датасете

accuracy = accuracy_score(y_true, y_pred_ygpt_ft)

precision = precision_score(y_true, y_pred_ygpt_ft, average='weighted')
recall = recall_score(y_true, y_pred_ygpt_ft, average='weighted')
f1 = f1_score(y_true, y_pred_ygpt_ft, average='weighted')

print("Accuracy:", accuracy)
print("Precision (weighted):", precision)
print("Recall (weighted):", recall)
print("F1-score (weighted):", f1)

print("\nОтчет по классам:")
print(classification_report(y_true, y_pred_ygpt_ft))
# Out:
# Accuracy: 0.49777777777777776
# Precision (weighted): 0.5982512445137202
# Recall (weighted): 0.49777777777777776
# F1-score (weighted): 0.4558987051052136
#
# Отчет по классам:
#                                              precision    recall  f1-score   support
#
#                    гранты субсидии конкурсы       1.00      0.45      0.62       100
#  пожертвования от физических лиц (напрямую)       0.48      0.61      0.54       100
# пожертвования от юридических лиц (напрямую)       0.31      0.78      0.44       100
#               пожертвования через платформы       0.00      0.00      0.00       100
#                             продажа товаров       0.83      0.05      0.09       100
#                               продажа услуг       0.41      0.80      0.54       100
#                  прочие недоходные операции       0.49      0.81      0.61       100
#                           финансовые доходы       1.00      0.38      0.55       100
#            членские и учредительские взносы       0.87      0.60      0.71       100
#
#                                    accuracy                           0.50       900
#                                   macro avg       0.60      0.50      0.46       900
#                                weighted avg       0.60      0.50      0.46       900
# /opt/anaconda3/envs/datasphere_cli_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/datasphere_cli_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/datasphere_cli_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/datasphere_cli_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
