# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
import time


from __future__ import annotations
from yandex_cloud_ml_sdk import YCloudML


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option("display.max_colwidth", None)

# %%
X_test = pd.read_csv('X_test_balanced.csv',index_col=0)

# %%
X_test.head(10)
# Out:
#                                                                                                                                                                                                   purpose
# 393593       Перечисление средств по соглашению №2140 о предоставлении гранта победителю конкурса на предоставление грантов Раиса РТ на развитие гражданского общества от 26.11.2024г. НДС не облагается.
# 429170                                                                                              ЗА 27/02/2025;СУМ:1500.00;КОМ:0.00;СЛЮСАРЕНКО ВИКТОРИЯ АНАТОЛЬЕВНА;Попечительский взнос котёнок Тужур
# 379020                                                                                                 Перевод с карты *6947, Благотворительное пожертвование на уставную деятельность. НДС не облагается
# 570841                                                            ОПЛАТА ПО ДОГОВОРУ НХТК.8190 (ДС НХТК.8190-2), СЧЕТ №21 ОТ 02.06.2025 (КВОТИРУЕМЫЕ РАБОЧИЕ МЕСТА). СУММА 80143-68 РУБ. БЕЗ НАЛОГА (НДС)
# 485026                                                                                                  БЛАГОТВОРИТЕЛЬНАЯ ПОМОЩЬ ПО СОГЛАШЕНИЮ №БС2025-005 ОТ 16.01.2025 СУММА 310750-00 БЕЗ НАЛОГА (НДС)
# 591200                     Выплата процентов по депозитной сделке № UNV-0000006342917 от 22.08.2025 за период с 23.08.2025 по 25.08.2025 согласно Правилам Банковского обслуживания. НДС не предусмотрен.
# 396289                                                                                                 Перевод с карты *3120, Благотворительное пожертвование на уставную деятельность. НДС не облагается
# 402359                                                                                                                        Благотворительное пожертвование на уставную деятельность. НДС не облагается
# 147304  Оплата по договору о предоставлении целевого гранта в рамках Благотворительной программы - акции "Добрый новогодний подарок" (2023-2024) № 24-1-000496 от 15.04.2024. 1 транш. НДС не облагается.
# 171375                                                                                                             Благотворительное пожертвование по договору 111-77/2024 от 29.02.2024НДС не облагается

# %%
y_pred_ygpt_ft = pd.DataFrame(columns=["universal_category"])

sdk = YCloudML(
        folder_id="YOUR_FOLDER_ID",
        auth="YOUR_YANDEX_CLOUD_TOKEN",
    )

model = sdk.models.text_classifiers(
        "cls://YOUR_FOLDER_ID/yandexgpt-lite/rc@tamr8d1155e1t47dmom70"
    )

for index__, text in tqdm(X_test['purpose'].items(), total=len(X_test)):
    attempts = 0
    max_attempts = 3
    while attempts < max_attempts:
        try:
            result = model.run(str(text))  # приводим текст к строке
            print(result, "\n")
            best_label = max(result, key=lambda x: x.confidence).label
            y_pred_ygpt_ft.loc[index__, "universal_category"] = best_label
            break
        except Exception as e:
            attempts += 1
            print(f"Ошибка на index {index__}, попытка {attempts}/{max_attempts}: {e}")
            time.sleep(2)
    else:
        # если все попытки неудачные, присваиваем NaN
        y_pred_ygpt_ft.loc[index__, "universal_category"] = np.nan

        
y_pred_ygpt_ft.to_csv("y_pred_ygpt_ft.csv", index=True, header=["universal_category"])
# Out:
#   0%|          | 1/900 [00:02<41:28,  2.77s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.11525197327136993), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=6.615401071030647e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.6964172124862671), TextClassificationLabel(label='пожертвования через платформы', confidence=1.8732625903794542e-05), TextClassificationLabel(label='продажа товаров', confidence=0.00016501691425219178), TextClassificationLabel(label='продажа услуг', confidence=0.036009784787893295), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0015056583797559142), TextClassificationLabel(label='финансовые доходы', confidence=0.00010166396532440558), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.1504637748003006)), model_version='', input_tokens=46)
#   0%|          | 2/900 [00:03<21:03,  1.41s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.004756641108542681), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.30111458897590637), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0004735076508950442), TextClassificationLabel(label='пожертвования через платформы', confidence=8.084953879006207e-05), TextClassificationLabel(label='продажа товаров', confidence=2.1506843040697277e-05), TextClassificationLabel(label='продажа услуг', confidence=0.10165181010961533), TextClassificationLabel(label='прочие недоходные операции', confidence=3.947995355702005e-05), TextClassificationLabel(label='финансовые доходы', confidence=4.4462009896051313e-07), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.5918611884117126)), model_version='', input_tokens=52)
#   0%|          | 3/900 [00:06<32:10,  2.15s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.000180750124854967), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.09698113799095154), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.8509824275970459), TextClassificationLabel(label='пожертвования через платформы', confidence=0.00714463833719492), TextClassificationLabel(label='продажа товаров', confidence=3.2280368031933904e-05), TextClassificationLabel(label='продажа услуг', confidence=0.03937571868300438), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0029228623025119305), TextClassificationLabel(label='финансовые доходы', confidence=2.465372563165147e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.002355476375669241)), model_version='', input_tokens=23)
#   0%|          | 4/900 [00:06<21:52,  1.47s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0072130076587200165), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.0010659192921593785), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.18297424912452698), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0007975573535077274), TextClassificationLabel(label='продажа товаров', confidence=0.013404304161667824), TextClassificationLabel(label='продажа услуг', confidence=0.7932530045509338), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0011638437863439322), TextClassificationLabel(label='финансовые доходы', confidence=0.00012594566214829683), TextClassificationLabel(label='членские и учредительские взносы', confidence=2.1627865862683393e-06)), model_version='', input_tokens=80)
#   1%|          | 5/900 [00:09<26:52,  1.80s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.018771545961499214), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.014873099513351917), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.9379711747169495), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0005719953333027661), TextClassificationLabel(label='продажа товаров', confidence=0.00029559031827375293), TextClassificationLabel(label='продажа услуг', confidence=0.026987649500370026), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0004437336465343833), TextClassificationLabel(label='финансовые доходы', confidence=3.4145200515922625e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=8.176245319191366e-05)), model_version='', input_tokens=55)
#   1%|          | 6/900 [00:11<30:08,  2.02s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=5.273144552120357e-07), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=2.1019266114308266e-06), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0013630276080220938), TextClassificationLabel(label='пожертвования через платформы', confidence=7.334254803481599e-08), TextClassificationLabel(label='продажа товаров', confidence=0.0007016263552941382), TextClassificationLabel(label='продажа услуг', confidence=0.00022131622245069593), TextClassificationLabel(label='прочие недоходные операции', confidence=4.783962504006922e-05), TextClassificationLabel(label='финансовые доходы', confidence=0.9976589679718018), TextClassificationLabel(label='членские и учредительские взносы', confidence=4.663327672460582e-06)), model_version='', input_tokens=74)
#   1%|          | 7/900 [00:11<22:26,  1.51s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0001565644342917949), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.06322432309389114), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.871932864189148), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0064210365526378155), TextClassificationLabel(label='продажа товаров', confidence=4.850140248890966e-05), TextClassificationLabel(label='продажа услуг', confidence=0.052108582109212875), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0018668044358491898), TextClassificationLabel(label='финансовые доходы', confidence=3.0233075449359603e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.004211018793284893)), model_version='', input_tokens=23)
#   1%|          | 8/900 [00:15<30:34,  2.06s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0001943165552802384), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.652540922164917), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.29183435440063477), TextClassificationLabel(label='пожертвования через платформы', confidence=0.029065320268273354), TextClassificationLabel(label='продажа товаров', confidence=0.00010815344285219908), TextClassificationLabel(label='продажа услуг', confidence=0.008294887840747833), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0006916082929819822), TextClassificationLabel(label='финансовые доходы', confidence=7.743333299004007e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.01726272702217102)), model_version='', input_tokens=14)
#   1%|          | 9/900 [00:18<34:13,  2.30s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.001459035207517445), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.03893740102648735), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.5369895100593567), TextClassificationLabel(label='пожертвования через платформы', confidence=0.002216089516878128), TextClassificationLabel(label='продажа товаров', confidence=0.00030463808798231184), TextClassificationLabel(label='продажа услуг', confidence=0.4182078242301941), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0003332750638946891), TextClassificationLabel(label='финансовые доходы', confidence=1.715297003102023e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0015350403264164925)), model_version='', input_tokens=68)
#   1%|          | 10/900 [00:20<34:20,  2.31s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.001034068176522851), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.07464903593063354), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.9023343324661255), TextClassificationLabel(label='пожертвования через платформы', confidence=0.012802161276340485), TextClassificationLabel(label='продажа товаров', confidence=0.0007897565374150872), TextClassificationLabel(label='продажа услуг', confidence=0.0044524818658828735), TextClassificationLabel(label='прочие недоходные операции', confidence=0.003738397266715765), TextClassificationLabel(label='финансовые доходы', confidence=9.542058251099661e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00019016583974007517)), model_version='', input_tokens=35)
#   1%|          | 11/900 [00:20<25:26,  1.72s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0001943165552802384), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.652540922164917), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.29183435440063477), TextClassificationLabel(label='пожертвования через платформы', confidence=0.029065320268273354), TextClassificationLabel(label='продажа товаров', confidence=0.00010815344285219908), TextClassificationLabel(label='продажа услуг', confidence=0.008294887840747833), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0006916082929819822), TextClassificationLabel(label='финансовые доходы', confidence=7.743333299004007e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.01726272702217102)), model_version='', input_tokens=14)
#   1%|▏         | 12/900 [00:23<28:51,  1.95s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0028901754412800074), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.11505374312400818), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.02100405842065811), TextClassificationLabel(label='пожертвования через платформы', confidence=0.00034450870589353144), TextClassificationLabel(label='продажа товаров', confidence=0.002242095535621047), TextClassificationLabel(label='продажа услуг', confidence=0.8530492186546326), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0014646697090938687), TextClassificationLabel(label='финансовые доходы', confidence=0.0033988142386078835), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0005526780732907355)), model_version='', input_tokens=49)
#   1%|▏         | 13/900 [00:25<30:20,  2.05s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.011952108703553677), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.020935671404004097), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.2436961978673935), TextClassificationLabel(label='пожертвования через платформы', confidence=0.012235544621944427), TextClassificationLabel(label='продажа товаров', confidence=0.003926020581275225), TextClassificationLabel(label='продажа услуг', confidence=0.30390089750289917), TextClassificationLabel(label='прочие недоходные операции', confidence=0.058658238500356674), TextClassificationLabel(label='финансовые доходы', confidence=0.028172025457024574), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.31652331352233887)), model_version='', input_tokens=66)
#   2%|▏         | 14/900 [00:25<22:54,  1.55s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0001943165552802384), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.652540922164917), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.29183435440063477), TextClassificationLabel(label='пожертвования через платформы', confidence=0.029065320268273354), TextClassificationLabel(label='продажа товаров', confidence=0.00010815344285219908), TextClassificationLabel(label='продажа услуг', confidence=0.008294887840747833), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0006916082929819822), TextClassificationLabel(label='финансовые доходы', confidence=7.743333299004007e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.01726272702217102)), model_version='', input_tokens=14)
#   2%|▏         | 15/900 [00:28<27:19,  1.85s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=9.517287980997935e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=4.729839201900177e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.27551519870758057), TextClassificationLabel(label='пожертвования через платформы', confidence=2.0063555439264746e-06), TextClassificationLabel(label='продажа товаров', confidence=0.0029956416692584753), TextClassificationLabel(label='продажа услуг', confidence=0.00398216862231493), TextClassificationLabel(label='прочие недоходные операции', confidence=0.1327110379934311), TextClassificationLabel(label='финансовые доходы', confidence=0.5844060182571411), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00024541743914596736)), model_version='', input_tokens=90)
#   2%|▏         | 16/900 [00:28<20:43,  1.41s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0024431110359728336), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.12276408076286316), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.022764582186937332), TextClassificationLabel(label='пожертвования через платформы', confidence=0.00021641537023242563), TextClassificationLabel(label='продажа товаров', confidence=0.0023865164257586002), TextClassificationLabel(label='продажа услуг', confidence=0.8446948528289795), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0019251253688707948), TextClassificationLabel(label='финансовые доходы', confidence=0.0023040734231472015), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0005012190085835755)), model_version='', input_tokens=49)
#   2%|▏         | 17/900 [00:31<25:39,  1.74s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00018017110414803028), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.8820470571517944), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.07492031902074814), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0006933695403859019), TextClassificationLabel(label='продажа товаров', confidence=4.627176531357691e-05), TextClassificationLabel(label='продажа услуг', confidence=0.0018357272492721677), TextClassificationLabel(label='прочие недоходные операции', confidence=0.00560495862737298), TextClassificationLabel(label='финансовые доходы', confidence=7.108816362233483e-07), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.03467147424817085)), model_version='', input_tokens=11)
#   2%|▏         | 18/900 [00:31<19:32,  1.33s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=8.564963354729116e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.0009898273274302483), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.6953830718994141), TextClassificationLabel(label='пожертвования через платформы', confidence=0.004528012126684189), TextClassificationLabel(label='продажа товаров', confidence=0.0032265582121908665), TextClassificationLabel(label='продажа услуг', confidence=0.23475098609924316), TextClassificationLabel(label='прочие недоходные операции', confidence=0.058320123702287674), TextClassificationLabel(label='финансовые доходы', confidence=0.0007471609278582036), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0019685067236423492)), model_version='', input_tokens=54)
#   2%|▏         | 19/900 [00:34<23:59,  1.63s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00036087591433897614), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.010691518895328045), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.027115752920508385), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0009733285987749696), TextClassificationLabel(label='продажа товаров', confidence=0.04040851816534996), TextClassificationLabel(label='продажа услуг', confidence=0.8953235745429993), TextClassificationLabel(label='прочие недоходные операции', confidence=0.019722409546375275), TextClassificationLabel(label='финансовые доходы', confidence=0.0009470747318118811), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.004456888418644667)), model_version='', input_tokens=53)
#   2%|▏         | 20/900 [00:36<28:26,  1.94s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.8660399317741394), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.0807955339550972), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.004753365181386471), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0004780585295520723), TextClassificationLabel(label='продажа товаров', confidence=0.001928049954585731), TextClassificationLabel(label='продажа услуг', confidence=0.020367305725812912), TextClassificationLabel(label='прочие недоходные операции', confidence=0.025027763098478317), TextClassificationLabel(label='финансовые доходы', confidence=6.623245280934498e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.000543831498362124)), model_version='', input_tokens=110)
#   2%|▏         | 21/900 [00:38<29:52,  2.04s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0136220408603549), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.04843602329492569), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.7517706751823425), TextClassificationLabel(label='пожертвования через платформы', confidence=0.10174109041690826), TextClassificationLabel(label='продажа товаров', confidence=0.0008854056941345334), TextClassificationLabel(label='продажа услуг', confidence=0.02786884643137455), TextClassificationLabel(label='прочие недоходные операции', confidence=0.05542381480336189), TextClassificationLabel(label='финансовые доходы', confidence=1.983043330255896e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00023232919920701534)), model_version='', input_tokens=50)
#   2%|▏         | 22/900 [00:41<32:46,  2.24s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=1.5827532479306683e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=8.539586269762367e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.006385281216353178), TextClassificationLabel(label='пожертвования через платформы', confidence=0.00013356168346945196), TextClassificationLabel(label='продажа товаров', confidence=9.695537301013246e-05), TextClassificationLabel(label='продажа услуг', confidence=0.0003512015100568533), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9550923705101013), TextClassificationLabel(label='финансовые доходы', confidence=0.0378371886909008), TextClassificationLabel(label='членские и учредительские взносы', confidence=2.3251443508343073e-06)), model_version='', input_tokens=25)
#   3%|▎         | 23/900 [00:44<36:11,  2.48s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0009523843764327466), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.14812973141670227), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.00463318545371294), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0015980618773028255), TextClassificationLabel(label='продажа товаров', confidence=0.00018035121320281178), TextClassificationLabel(label='продажа услуг', confidence=0.007736426778137684), TextClassificationLabel(label='прочие недоходные операции', confidence=0.8343091607093811), TextClassificationLabel(label='финансовые доходы', confidence=0.0009087714133784175), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0015519227599725127)), model_version='', input_tokens=18)
#   3%|▎         | 24/900 [00:47<35:26,  2.43s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00016870556282810867), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.04516142979264259), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.8131116628646851), TextClassificationLabel(label='пожертвования через платформы', confidence=0.005866321735084057), TextClassificationLabel(label='продажа товаров', confidence=6.950760871404782e-05), TextClassificationLabel(label='продажа услуг', confidence=0.12840192019939423), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0011328045511618257), TextClassificationLabel(label='финансовые доходы', confidence=1.4343706425279379e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.006073261611163616)), model_version='', input_tokens=23)
#   3%|▎         | 25/900 [00:49<35:22,  2.43s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=5.136389063409297e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.6704116463661194), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.005671371705830097), TextClassificationLabel(label='пожертвования через платформы', confidence=0.00014492175250779837), TextClassificationLabel(label='продажа товаров', confidence=0.003343809163197875), TextClassificationLabel(label='продажа услуг', confidence=0.3099488914012909), TextClassificationLabel(label='прочие недоходные операции', confidence=0.010380438528954983), TextClassificationLabel(label='финансовые доходы', confidence=9.596038580639288e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=8.420255471719429e-05)), model_version='', input_tokens=29)
#   3%|▎         | 26/900 [00:50<27:57,  1.92s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00019059352052863687), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.11633222550153732), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.7675233483314514), TextClassificationLabel(label='пожертвования через платформы', confidence=0.006225885823369026), TextClassificationLabel(label='продажа товаров', confidence=4.93323641421739e-05), TextClassificationLabel(label='продажа услуг', confidence=0.1030646339058876), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0015989396488294005), TextClassificationLabel(label='финансовые доходы', confidence=1.4870237464492675e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.005000197794288397)), model_version='', input_tokens=23)
#   3%|▎         | 27/900 [00:52<29:59,  2.06s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.274025022983551), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.002453214256092906), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.09058474749326706), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0010326876072213054), TextClassificationLabel(label='продажа товаров', confidence=0.001580823794938624), TextClassificationLabel(label='продажа услуг', confidence=0.17709670960903168), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0015994578134268522), TextClassificationLabel(label='финансовые доходы', confidence=0.00027740176301449537), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.4513499140739441)), model_version='', input_tokens=49)
#   3%|▎         | 28/900 [00:52<22:33,  1.55s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=2.263460191898048e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.000123562291264534), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.00038734806003049016), TextClassificationLabel(label='пожертвования через платформы', confidence=1.2426987268554512e-05), TextClassificationLabel(label='продажа товаров', confidence=3.087285904257442e-06), TextClassificationLabel(label='продажа услуг', confidence=8.009005250642076e-05), TextClassificationLabel(label='прочие недоходные операции', confidence=8.821979281492531e-05), TextClassificationLabel(label='финансовые доходы', confidence=5.302395038597751e-07), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.9992820620536804)), model_version='', input_tokens=26)
#   3%|▎         | 29/900 [00:55<28:16,  1.95s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=6.0309354012133554e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.016591979190707207), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0002197424037149176), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0005049640312790871), TextClassificationLabel(label='продажа товаров', confidence=8.115510718198493e-05), TextClassificationLabel(label='продажа услуг', confidence=0.0014928934397175908), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9795021414756775), TextClassificationLabel(label='финансовые доходы', confidence=2.6040250304504298e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0015208523254841566)), model_version='', input_tokens=8)
#   3%|▎         | 30/900 [00:58<29:32,  2.04s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=8.458523370791227e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.016285225749015808), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.013848112896084785), TextClassificationLabel(label='пожертвования через платформы', confidence=0.006831921171396971), TextClassificationLabel(label='продажа товаров', confidence=0.0022158350329846144), TextClassificationLabel(label='продажа услуг', confidence=0.8939317464828491), TextClassificationLabel(label='прочие недоходные операции', confidence=0.06526408344507217), TextClassificationLabel(label='финансовые доходы', confidence=0.00010363598994445056), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.001434848178178072)), model_version='', input_tokens=25)
#   3%|▎         | 31/900 [01:01<33:47,  2.33s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0004648736212402582), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.23408633470535278), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.39432454109191895), TextClassificationLabel(label='пожертвования через платформы', confidence=0.09128984063863754), TextClassificationLabel(label='продажа товаров', confidence=0.00013318851415533572), TextClassificationLabel(label='продажа услуг', confidence=0.03149505704641342), TextClassificationLabel(label='прочие недоходные операции', confidence=0.000700589211191982), TextClassificationLabel(label='финансовые доходы', confidence=1.956606502062641e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.24748601019382477)), model_version='', input_tokens=11)
#   4%|▎         | 32/900 [01:03<33:00,  2.28s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=8.083140528469812e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=4.526059638010338e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0037680459208786488), TextClassificationLabel(label='пожертвования через платформы', confidence=4.8179656005231664e-05), TextClassificationLabel(label='продажа товаров', confidence=8.195635746233165e-05), TextClassificationLabel(label='продажа услуг', confidence=0.0004109581932425499), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9891728162765503), TextClassificationLabel(label='финансовые доходы', confidence=0.0064599341712892056), TextClassificationLabel(label='членские и учредительские взносы', confidence=4.678163804783253e-06)), model_version='', input_tokens=23)
#   4%|▎         | 33/900 [01:05<32:46,  2.27s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0001197424135170877), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.008585275150835514), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.9836394190788269), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0022671089973300695), TextClassificationLabel(label='продажа товаров', confidence=7.177058705565287e-06), TextClassificationLabel(label='продажа услуг', confidence=0.0023470832966268063), TextClassificationLabel(label='прочие недоходные операции', confidence=0.002706757979467511), TextClassificationLabel(label='финансовые доходы', confidence=3.601272737796535e-07), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0003270868328399956)), model_version='', input_tokens=18)
#   4%|▍         | 34/900 [01:05<24:34,  1.70s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.000339225196512416), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.20068195462226868), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0009854224044829607), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0009275285992771387), TextClassificationLabel(label='продажа товаров', confidence=0.05551011115312576), TextClassificationLabel(label='продажа услуг', confidence=0.6895894408226013), TextClassificationLabel(label='прочие недоходные операции', confidence=0.05148908495903015), TextClassificationLabel(label='финансовые доходы', confidence=0.00019864275236614048), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0002784945536404848)), model_version='', input_tokens=75)
#   4%|▍         | 35/900 [01:08<27:47,  1.93s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=6.30422291578725e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=6.182287324918434e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0023085863795131445), TextClassificationLabel(label='пожертвования через платформы', confidence=4.3159325286978856e-05), TextClassificationLabel(label='продажа товаров', confidence=0.0002083287254208699), TextClassificationLabel(label='продажа услуг', confidence=0.002207175362855196), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9923858642578125), TextClassificationLabel(label='финансовые доходы', confidence=0.0002978348347824067), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0024241080973297358)), model_version='', input_tokens=43)
#   4%|▍         | 36/900 [01:08<21:00,  1.46s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=3.412404339542263e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.0009099182207137346), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0026914284098893404), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0010577162029221654), TextClassificationLabel(label='продажа товаров', confidence=0.0001175048528239131), TextClassificationLabel(label='продажа услуг', confidence=0.0009764381102286279), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9939562678337097), TextClassificationLabel(label='финансовые доходы', confidence=0.0002868782030418515), TextClassificationLabel(label='членские и учредительские взносы', confidence=5.860784995093127e-07)), model_version='', input_tokens=23)
#   4%|▍         | 37/900 [01:11<24:43,  1.72s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.3123931288719177), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.005478357896208763), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.21792589128017426), TextClassificationLabel(label='пожертвования через платформы', confidence=0.008771506138145924), TextClassificationLabel(label='продажа товаров', confidence=0.005320187658071518), TextClassificationLabel(label='продажа услуг', confidence=0.17972107231616974), TextClassificationLabel(label='прочие недоходные операции', confidence=0.010705174878239632), TextClassificationLabel(label='финансовые доходы', confidence=0.0005751635762862861), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.2591094970703125)), model_version='', input_tokens=49)
#   4%|▍         | 38/900 [01:13<26:33,  1.85s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0027005241718143225), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.1378358006477356), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.025114024057984352), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0002913830103352666), TextClassificationLabel(label='продажа товаров', confidence=0.003232104005292058), TextClassificationLabel(label='продажа услуг', confidence=0.8255931735038757), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0017745094373822212), TextClassificationLabel(label='финансовые доходы', confidence=0.0029892076272517443), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00046928072697483003)), model_version='', input_tokens=49)
#   4%|▍         | 39/900 [01:16<30:48,  2.15s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0003357163514010608), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.011369932442903519), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.01919039525091648), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0011268755188211799), TextClassificationLabel(label='продажа товаров', confidence=0.056998953223228455), TextClassificationLabel(label='продажа услуг', confidence=0.8866210579872131), TextClassificationLabel(label='прочие недоходные операции', confidence=0.020328566431999207), TextClassificationLabel(label='финансовые доходы', confidence=0.0006969650858081877), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0033315354958176613)), model_version='', input_tokens=53)
#   4%|▍         | 40/900 [01:19<34:44,  2.42s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=2.970946070490754e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=1.0698786354623735e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.1281242072582245), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0004932128940708935), TextClassificationLabel(label='продажа товаров', confidence=2.3231776140164584e-05), TextClassificationLabel(label='продажа услуг', confidence=0.8687562942504883), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0023581627756357193), TextClassificationLabel(label='финансовые доходы', confidence=1.1679927638397203e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00023009443248156458)), model_version='', input_tokens=50)
#   5%|▍         | 41/900 [01:21<35:43,  2.50s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.6380190253257751), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.14729328453540802), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.03903359919786453), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0012054871767759323), TextClassificationLabel(label='продажа товаров', confidence=0.002149013103917241), TextClassificationLabel(label='продажа услуг', confidence=0.141495019197464), TextClassificationLabel(label='прочие недоходные операции', confidence=0.020832059904932976), TextClassificationLabel(label='финансовые доходы', confidence=0.0015061248559504747), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.008466375060379505)), model_version='', input_tokens=131)
#   5%|▍         | 42/900 [01:24<35:44,  2.50s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.013186202384531498), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.02144516259431839), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.9463462233543396), TextClassificationLabel(label='пожертвования через платформы', confidence=0.004297688137739897), TextClassificationLabel(label='продажа товаров', confidence=2.7309612050885335e-05), TextClassificationLabel(label='продажа услуг', confidence=0.014418707229197025), TextClassificationLabel(label='прочие недоходные операции', confidence=0.00020617456175386906), TextClassificationLabel(label='финансовые доходы', confidence=4.4837014456788893e-07), TextClassificationLabel(label='членские и учредительские взносы', confidence=7.195125363068655e-05)), model_version='', input_tokens=72)
#   5%|▍         | 43/900 [01:27<37:12,  2.60s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=7.039228512439877e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.04263085871934891), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.9114879965782166), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0036051510833203793), TextClassificationLabel(label='продажа товаров', confidence=2.4043505618465133e-05), TextClassificationLabel(label='продажа услуг', confidence=0.038065072149038315), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0009446017211303115), TextClassificationLabel(label='финансовые доходы', confidence=1.5223400623654015e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0031567756086587906)), model_version='', input_tokens=23)
#   5%|▍         | 44/900 [01:30<38:41,  2.71s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=1.0068773690363741e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=2.04190860131348e-06), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0015180972404778004), TextClassificationLabel(label='пожертвования через платформы', confidence=1.1121709064809693e-07), TextClassificationLabel(label='продажа товаров', confidence=0.002136683091521263), TextClassificationLabel(label='продажа услуг', confidence=0.00021131508401595056), TextClassificationLabel(label='прочие недоходные операции', confidence=8.699391037225723e-05), TextClassificationLabel(label='финансовые доходы', confidence=0.996038556098938), TextClassificationLabel(label='членские и учредительские взносы', confidence=5.143393991602352e-06)), model_version='', input_tokens=74)
#   5%|▌         | 45/900 [01:33<40:05,  2.81s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00693256501108408), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.14560648798942566), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0022772045340389013), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0044672670774161816), TextClassificationLabel(label='продажа товаров', confidence=3.093461782555096e-05), TextClassificationLabel(label='продажа услуг', confidence=0.0026364491786807775), TextClassificationLabel(label='прочие недоходные операции', confidence=0.5839548707008362), TextClassificationLabel(label='финансовые доходы', confidence=0.0002259145985590294), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.25386837124824524)), model_version='', input_tokens=9)
#   5%|▌         | 46/900 [01:35<38:51,  2.73s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=8.694737516634632e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=6.919556471984833e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.00912499614059925), TextClassificationLabel(label='пожертвования через платформы', confidence=2.6161284040426835e-05), TextClassificationLabel(label='продажа товаров', confidence=0.0003327026788610965), TextClassificationLabel(label='продажа услуг', confidence=0.002211540937423706), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9879062175750732), TextClassificationLabel(label='финансовые доходы', confidence=0.00019368508947081864), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00012677394261118025)), model_version='', input_tokens=35)
#   5%|▌         | 47/900 [01:38<38:26,  2.70s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0012715276097878814), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.12312709540128708), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.03003394976258278), TextClassificationLabel(label='пожертвования через платформы', confidence=0.005523264408111572), TextClassificationLabel(label='продажа товаров', confidence=0.019793154671788216), TextClassificationLabel(label='продажа услуг', confidence=0.7852485179901123), TextClassificationLabel(label='прочие недоходные операции', confidence=0.03296973928809166), TextClassificationLabel(label='финансовые доходы', confidence=0.000824173039291054), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0012085698544979095)), model_version='', input_tokens=30)
#   5%|▌         | 48/900 [01:38<28:28,  2.01s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.08587038516998291), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=9.897032214212231e-06), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.037222057580947876), TextClassificationLabel(label='пожертвования через платформы', confidence=8.045030313041934e-07), TextClassificationLabel(label='продажа товаров', confidence=0.0002835009654518217), TextClassificationLabel(label='продажа услуг', confidence=0.8471701741218567), TextClassificationLabel(label='прочие недоходные операции', confidence=1.747190981404856e-05), TextClassificationLabel(label='финансовые доходы', confidence=9.540243627270684e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.029330279678106308)), model_version='', input_tokens=3)
#   5%|▌         | 49/900 [01:41<32:52,  2.32s/it]
# ...
#  98%|█████████▊| 885/900 [29:53<00:33,  2.26s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0001245474413735792), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.3447131812572479), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.5287137031555176), TextClassificationLabel(label='пожертвования через платформы', confidence=0.027925189584493637), TextClassificationLabel(label='продажа товаров', confidence=0.004424883984029293), TextClassificationLabel(label='продажа услуг', confidence=0.0019983507227152586), TextClassificationLabel(label='прочие недоходные операции', confidence=0.09178698807954788), TextClassificationLabel(label='финансовые доходы', confidence=3.513022238621488e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00027794440393336117)), model_version='', input_tokens=45)
#  98%|█████████▊| 886/900 [29:56<00:34,  2.44s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.3391537368297577), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.08055607974529266), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.37467649579048157), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0056559243239462376), TextClassificationLabel(label='продажа товаров', confidence=0.005476559046655893), TextClassificationLabel(label='продажа услуг', confidence=0.1827811449766159), TextClassificationLabel(label='прочие недоходные операции', confidence=0.010281641036272049), TextClassificationLabel(label='финансовые доходы', confidence=3.7812751543242484e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0013806401984766126)), model_version='', input_tokens=127)
#  99%|█████████▊| 887/900 [29:58<00:31,  2.44s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=5.187799615669064e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.002780372044071555), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.012894030660390854), TextClassificationLabel(label='пожертвования через платформы', confidence=0.004111131187528372), TextClassificationLabel(label='продажа товаров', confidence=0.0028227779548615217), TextClassificationLabel(label='продажа услуг', confidence=0.9547523856163025), TextClassificationLabel(label='прочие недоходные операции', confidence=0.021912073716521263), TextClassificationLabel(label='финансовые доходы', confidence=8.963714935816824e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0005856503266841173)), model_version='', input_tokens=25)
#  99%|█████████▊| 888/900 [29:58<00:21,  1.82s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00013125957048032433), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.0237287450581789), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.8630194067955017), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0016595240449532866), TextClassificationLabel(label='продажа товаров', confidence=4.58072499895934e-05), TextClassificationLabel(label='продажа услуг', confidence=0.10823071002960205), TextClassificationLabel(label='прочие недоходные операции', confidence=0.00030399783281609416), TextClassificationLabel(label='финансовые доходы', confidence=6.175168891786598e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.002874409779906273)), model_version='', input_tokens=23)
#  99%|█████████▉| 889/900 [30:01<00:22,  2.05s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.002564213005825877), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.10333134233951569), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.8926466107368469), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0004959853831678629), TextClassificationLabel(label='продажа товаров', confidence=0.00018412555800750852), TextClassificationLabel(label='продажа услуг', confidence=0.000673338829074055), TextClassificationLabel(label='прочие недоходные операции', confidence=4.946002081851475e-05), TextClassificationLabel(label='финансовые доходы', confidence=1.3078076790407067e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=5.358359339879826e-05)), model_version='', input_tokens=53)
#  99%|█████████▉| 890/900 [30:01<00:15,  1.55s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.006917553022503853), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.3499849736690521), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.03220978006720543), TextClassificationLabel(label='пожертвования через платформы', confidence=0.00028719939291477203), TextClassificationLabel(label='продажа товаров', confidence=0.008839048445224762), TextClassificationLabel(label='продажа услуг', confidence=0.5872604250907898), TextClassificationLabel(label='прочие недоходные операции', confidence=0.012848188169300556), TextClassificationLabel(label='финансовые доходы', confidence=0.0006522900075651705), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0010004685027524829)), model_version='', input_tokens=47)
#  99%|█████████▉| 891/900 [30:04<00:16,  1.87s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00011699455353664234), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.09875611960887909), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.8497966527938843), TextClassificationLabel(label='пожертвования через платформы', confidence=0.005348851438611746), TextClassificationLabel(label='продажа товаров', confidence=6.141143967397511e-05), TextClassificationLabel(label='продажа услуг', confidence=0.042143937200307846), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0007293877424672246), TextClassificationLabel(label='финансовые доходы', confidence=4.106894994038157e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.003005565842613578)), model_version='', input_tokens=23)
#  99%|█████████▉| 892/900 [30:04<00:11,  1.42s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=7.632213964825496e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.0005041166441515088), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.007963097654283047), TextClassificationLabel(label='пожертвования через платформы', confidence=0.00046532193664461374), TextClassificationLabel(label='продажа товаров', confidence=4.223779615131207e-05), TextClassificationLabel(label='продажа услуг', confidence=0.0004612501070369035), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9903517365455627), TextClassificationLabel(label='финансовые доходы', confidence=6.909642252139747e-05), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.00013554870383813977)), model_version='', input_tokens=50)
#  99%|█████████▉| 893/900 [30:07<00:12,  1.80s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.4557785093784332), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.002057756297290325), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.1595836877822876), TextClassificationLabel(label='пожертвования через платформы', confidence=0.006289011333137751), TextClassificationLabel(label='продажа товаров', confidence=0.007410265970975161), TextClassificationLabel(label='продажа услуг', confidence=0.0949782207608223), TextClassificationLabel(label='прочие недоходные операции', confidence=0.006475984584540129), TextClassificationLabel(label='финансовые доходы', confidence=0.0007933358428999782), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.2666332423686981)), model_version='', input_tokens=49)
#  99%|█████████▉| 894/900 [30:07<00:08,  1.37s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=8.083140528469812e-06), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=4.526059638010338e-05), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.0037680459208786488), TextClassificationLabel(label='пожертвования через платформы', confidence=4.8179656005231664e-05), TextClassificationLabel(label='продажа товаров', confidence=8.195635746233165e-05), TextClassificationLabel(label='продажа услуг', confidence=0.0004109581932425499), TextClassificationLabel(label='прочие недоходные операции', confidence=0.9891728162765503), TextClassificationLabel(label='финансовые доходы', confidence=0.0064599341712892056), TextClassificationLabel(label='членские и учредительские взносы', confidence=4.678163804783253e-06)), model_version='', input_tokens=23)
#  99%|█████████▉| 895/900 [30:10<00:08,  1.66s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0008283288334496319), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.026046857237815857), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.9575608968734741), TextClassificationLabel(label='пожертвования через платформы', confidence=0.006274898070842028), TextClassificationLabel(label='продажа товаров', confidence=8.578396227676421e-05), TextClassificationLabel(label='продажа услуг', confidence=0.0020144109148532152), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0061866710893809795), TextClassificationLabel(label='финансовые доходы', confidence=4.8396000238426495e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0009972058469429612)), model_version='', input_tokens=37)
# 100%|█████████▉| 896/900 [30:12<00:07,  1.92s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=9.106640936806798e-05), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.036169230937957764), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.914774477481842), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0036787178833037615), TextClassificationLabel(label='продажа товаров', confidence=1.1265503417234868e-05), TextClassificationLabel(label='продажа услуг', confidence=0.04046807438135147), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0016016290755942464), TextClassificationLabel(label='финансовые доходы', confidence=6.344108442135621e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0031992478761821985)), model_version='', input_tokens=23)
# 100%|█████████▉| 897/900 [30:15<00:06,  2.07s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.002166186925023794), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.10315675288438797), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.7230767607688904), TextClassificationLabel(label='пожертвования через платформы', confidence=0.016676224768161774), TextClassificationLabel(label='продажа товаров', confidence=0.010384884662926197), TextClassificationLabel(label='продажа услуг', confidence=0.11252370476722717), TextClassificationLabel(label='прочие недоходные операции', confidence=0.02689691260457039), TextClassificationLabel(label='финансовые доходы', confidence=0.0007427884847857058), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.004375818185508251)), model_version='', input_tokens=42)
# 100%|█████████▉| 898/900 [30:17<00:04,  2.23s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00036517076659947634), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.01020057126879692), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=9.448198397876695e-06), TextClassificationLabel(label='пожертвования через платформы', confidence=2.8763442969648167e-05), TextClassificationLabel(label='продажа товаров', confidence=4.872296699431899e-07), TextClassificationLabel(label='продажа услуг', confidence=0.011832870543003082), TextClassificationLabel(label='прочие недоходные операции', confidence=0.00011532764619914815), TextClassificationLabel(label='финансовые доходы', confidence=6.305220381364052e-07), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.9774467349052429)), model_version='', input_tokens=51)
# 100%|█████████▉| 899/900 [30:20<00:02,  2.28s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.00036033039214089513), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.013774524442851543), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.013195185922086239), TextClassificationLabel(label='пожертвования через платформы', confidence=0.0011631608940660954), TextClassificationLabel(label='продажа товаров', confidence=0.03966376185417175), TextClassificationLabel(label='продажа услуг', confidence=0.9169592261314392), TextClassificationLabel(label='прочие недоходные операции', confidence=0.010885908268392086), TextClassificationLabel(label='финансовые доходы', confidence=0.0006058017024770379), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.0033921150024980307)), model_version='', input_tokens=54)
# 100%|██████████| 900/900 [30:22<00:00,  2.03s/it]
# TextClassifiersModelResult(predictions=(TextClassificationLabel(label='гранты субсидии конкурсы', confidence=0.0001943165552802384), TextClassificationLabel(label='пожертвования от физических лиц (напрямую)', confidence=0.652540922164917), TextClassificationLabel(label='пожертвования от юридических лиц (напрямую)', confidence=0.29183435440063477), TextClassificationLabel(label='пожертвования через платформы', confidence=0.029065320268273354), TextClassificationLabel(label='продажа товаров', confidence=0.00010815344285219908), TextClassificationLabel(label='продажа услуг', confidence=0.008294887840747833), TextClassificationLabel(label='прочие недоходные операции', confidence=0.0006916082929819822), TextClassificationLabel(label='финансовые доходы', confidence=7.743333299004007e-06), TextClassificationLabel(label='членские и учредительские взносы', confidence=0.01726272702217102)), model_version='', input_tokens=14)

# %%
y_pred_ygpt_ft.to_csv("y_pred_ygpt_ft.csv", index=True, header=["universal_category"])
